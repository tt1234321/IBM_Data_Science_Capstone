# %% [markdown]
# # This is PART 1 of week 3 assignment

# %%
from bs4 import BeautifulSoup # module for web scrapping.
import requests  # module that helps to download a web page
import pandas as pd #pandas module

# %%
url_toronto="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
#first I will try to check what data read_html method will give me

# %%
df_tor1 = pd.read_html(url_toronto, flavor='bs4')
len(df_tor1)
# Out:
# 3

# %%
df_tor1[0].shape
# Out:
# (20, 9)

# %%
df_tor1[0]
# Out:
#                                                     0  \
# 0                                     M1ANot assigned
# 1                     M1BScarborough(Malvern / Rouge)
# 2   M1CScarborough(Rouge Hill / Port Union / Highl...
# 3   M1EScarborough(Guildwood / Morningside / West ...
# 4                              M1GScarborough(Woburn)
# 5                           M1HScarborough(Cedarbrae)
# 6                 M1JScarborough(Scarborough Village)
# 7   M1KScarborough(Kennedy Park / Ionview / East B...
# 8   M1LScarborough(Golden Mile / Clairlea / Oakridge)
# 9   M1MScarborough(Cliffside / Cliffcrest / Scarbo...
# 10       M1NScarborough(Birch Cliff / Cliffside West)
# 11  M1PScarborough(Dorset Park / Wexford Heights /...
# 12                 M1RScarborough(Wexford / Maryvale)
# 13                          M1SScarborough(Agincourt)
# 14  M1TScarborough(Clarks Corners / Tam O'Shanter ...
# 15  M1VScarborough(Milliken / Agincourt North / St...
# ...

# %%
#I will try beautiful soup as read_html method data requires a lot of cleaning and pre processing

# %%
source = requests.get(url_toronto).text
soup = BeautifulSoup(source, 'html.parser')

# %%
#extracting beautifull soup - code follows also instructions from assignment i.e. if Neighborhood is Not assigned make Neighborhood' equal to Borough

# %%
table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        if cell['Neighborhood']=='Not assigned' :
            cell['Neighborhood']=cell['Borough']
        table_contents.append(cell)

# %%
df_toronto=pd.DataFrame(table_contents)

# %%
df_toronto
# Out:
#     PostalCode                                            Borough  \
# 0          M3A                                         North York
# 1          M4A                                         North York
# 2          M5A                                   Downtown Toronto
# 3          M6A                                         North York
# 4          M7A                                       Queen's Park
# 5          M9A                                          Etobicoke
# 6          M1B                                        Scarborough
# 7          M3B                                         North York
# 8          M4B                                          East York
# 9          M5B                                   Downtown Toronto
# 10         M6B                                         North York
# 11         M9B                                          Etobicoke
# 12         M1C                                        Scarborough
# ...

# %%
df_toronto.describe()
# Out:
#        PostalCode     Borough              Neighborhood
# count         103         103                       103
# unique        103          15                       103
# top           M5P  North York  Little Portugal, Trinity
# freq            1          24                         1

# %%
df_toronto.groupby(df_toronto["Borough"]).count()
# Out:
#                                                     PostalCode  Neighborhood
# Borough
# Central Toronto                                              9             9
# Downtown Toronto                                            17            17
# Downtown TorontoStn A PO Boxes25 The Esplanade               1             1
# East Toronto                                                 4             4
# East TorontoBusiness reply mail Processing Cent...           1             1
# East York                                                    4             4
# East YorkEast Toronto                                        1             1
# Etobicoke                                                   11            11
# EtobicokeNorthwest                                           1             1
# MississaugaCanada Post Gateway Processing Centre             1             1
# North York                                                  24            24
# ...

# %%
df_toronto.groupby(df_toronto["Borough"]).sum()
# Out:
#                                                                                            PostalCode  \
# Borough
# Central Toronto                                                           M4NM5NM4PM5PM4RM5RM4SM4TM4V
# Downtown Toronto                                    M5AM5BM5CM5EM5GM6GM5HM5JM5KM5LM5SM5TM5VM4WM4XM...
# Downtown TorontoStn A PO Boxes25 The Esplanade                                                    M5W
# East Toronto                                                                             M4EM4KM4LM4M
# East TorontoBusiness reply mail Processing Cent...                                                M7Y
# East York                                                                                M4BM4CM4GM4H
# East YorkEast Toronto                                                                             M4J
# Etobicoke                                                           M9AM9BM9CM9PM9RM8VM9VM8WM8XM8YM8Z
# ...

# %%
df_toronto.shape
# Out:
# (103, 3)

# %% [markdown]
# # This is PART 2 of week 3 assignment

# %%
#Geocoder was unable do perform task  succesfully, therefore I had to use csv file given in the link in the assignment

# %%
geo_coordinates="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv"

# %%
df_toronto_coord = pd.read_csv(geo_coordinates)

# %%
df_toronto_coord
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...

# %%
df_toronto_coord2 = df_toronto_coord.rename(columns={"Postal Code" : "PostalCode"}) #making same column name in both merged tables

# %%
df_toronto_coord2
# Out:
#     PostalCode   Latitude  Longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# 5          M1J  43.744734 -79.239476
# 6          M1K  43.727929 -79.262029
# 7          M1L  43.711112 -79.284577
# 8          M1M  43.716316 -79.239476
# 9          M1N  43.692657 -79.264848
# 10         M1P  43.757410 -79.273304
# 11         M1R  43.750072 -79.295849
# 12         M1S  43.794200 -79.262029
# 13         M1T  43.781638 -79.304302
# 14         M1V  43.815252 -79.284577
# 15         M1W  43.799525 -79.318389
# 16         M1X  43.836125 -79.205636
# 17         M2H  43.803762 -79.363452
# 18         M2J  43.778517 -79.346556
# 19         M2K  43.786947 -79.385975
# 20         M2L  43.757490 -79.374714
# 21         M2M  43.789053 -79.408493
# 22         M2N  43.770120 -79.408493
# 23         M2P  43.752758 -79.400049
# ...

# %%
df_toronto_merged = pd.merge(df_toronto, df_toronto_coord2, on="PostalCode")

# %%
df_toronto_merged
# Out:
#     PostalCode                                            Borough  \
# 0          M3A                                         North York
# 1          M4A                                         North York
# 2          M5A                                   Downtown Toronto
# 3          M6A                                         North York
# 4          M7A                                       Queen's Park
# 5          M9A                                          Etobicoke
# 6          M1B                                        Scarborough
# 7          M3B                                         North York
# 8          M4B                                          East York
# 9          M5B                                   Downtown Toronto
# 10         M6B                                         North York
# 11         M9B                                          Etobicoke
# 12         M1C                                        Scarborough
# ...

# %% [markdown]
# # This is PART 3 of week 3 assignment

# %%
#!pip install folium

# %%
#Import libraries
import numpy as np
import pandas as pd

from geopy.geocoders import Nominatim # This libraryconvert an address into latitude and longitude values

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans


import folium # map library

#Possible other libraries (uncoment 1st # below if necessary)
#import json # JSON files library
#import requests # requests library
#from pandas.io.json import json_normalize # converts JSON file into a pandas dataframe

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab

# %%
#using geocode to get coordinates of Toronto (similiar as in LAB):
address = 'Toronto, Canada'
geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Coordinates of {} are Latitude{}, Longitude {}.'.format(address, latitude, longitude))
# Out:
# Coordinates of Toronto, Canada are Latitude43.6534817, Longitude -79.3839347.

# %%
#Use folium for the map of Toronto
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# %%
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
neighborhoods=df_toronto_merged.copy()

# %%
#map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers for Boroughs and Neiborhoods to the Toronto map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
#map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
